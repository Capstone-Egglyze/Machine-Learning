# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization, Flatten,Input
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model, Sequential
from keras.callbacks import ModelCheckpoint
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import os
import seaborn as sns
sns.set_style('darkgrid')
from sklearn.metrics import confusion_matrix, classification_report
from IPython.display import display, HTML
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ### iterate through the folders to create a dataframe of the form filepaths labels

# %%
sdir = r'./dataset_split'

filepaths=[]
labels=[]
classlist=os.listdir(sdir)
for klass in classlist:
    classpath=os.path.join(sdir,klass)
    if os.path.isdir(classpath):
        flist=os.listdir(classpath)
        for f in flist:
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(klass)                   
Fseries= pd.Series(filepaths, name='filepaths')
Lseries=pd.Series(labels, name='labels')    
df=pd.concat([Fseries, Lseries], axis=1)
print (df.head())
print (df['labels'].value_counts())
# Out:
#                                            filepaths  labels
# 0  ./dataset_split\Mutu I\-11_jpg.rf.64d157fda032...  Mutu I
# 1  ./dataset_split\Mutu I\-11_jpg.rf.ca7485d8020b...  Mutu I
# 2  ./dataset_split\Mutu I\-11_jpg.rf.d726c1053caa...  Mutu I
# 3  ./dataset_split\Mutu I\-12_jpg.rf.08650c466b6f...  Mutu I
# 4  ./dataset_split\Mutu I\-12_jpg.rf.9a90d5f30eb8...  Mutu I
# labels
# Mutu I      598
# Mutu III    503
# Mutu II     478
# Name: count, dtype: int64

# %% [markdown]
# ### split df into train_df, test_df and valid_df

# %%
train_split=.75
test_split=.15
dummy_split=test_split/(1-train_split)
train_df, dummy_df=train_test_split(df, train_size=train_split, shuffle=True, random_state=123)
test_df, valid_df=train_test_split(dummy_df, train_size=dummy_split, shuffle=True, random_state=123)
print ('train_df length: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# Out:
# train_df length:  1184   test_df length:  237   valid_df length:  158

# %% [markdown]
# ### create train, test, valid  generators

# %%
height=128
width=128
channels=3
batch_size=32

img_shape=(height, width, channels)
img_size=(height, width)
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]  
test_steps=int(length/test_batch_size)
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps)

gen=ImageDataGenerator(
    rescale=1./255,
    )
train_gen=gen.flow_from_dataframe( train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)

validgen=ImageDataGenerator(rescale=1./255)
valid_gen=validgen.flow_from_dataframe( valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=False, batch_size=batch_size)

testgen=ImageDataGenerator(rescale=1./255)
test_gen=testgen.flow_from_dataframe( test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=False, batch_size=test_batch_size)

classes=list(train_gen.class_indices.keys())
print (classes)
class_count=len(classes)
# Out:
# test batch size:  79   test steps:  3
# Found 1184 validated image filenames belonging to 3 classes.
# Found 158 validated image filenames belonging to 3 classes.
# Found 237 validated image filenames belonging to 3 classes.
# ['Mutu I', 'Mutu II', 'Mutu III']

# %% [markdown]
# ### create function to show some image examples

# %%
def show_image_samples(gen):
    test_dict=test_gen.class_indices
    classes=list(test_dict.keys())    
    images,labels=next(gen) # get a sample batch from the generator 
    plt.figure(figsize=(20, 20))
    length=len(labels)
    if length<25:   #show maximum of 25 images
        r=length
    else:
        r=25
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image=images[i]
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=16)
        plt.axis('off')
    plt.show()

# %%
show_image_samples(train_gen)

# %% [markdown]
# ### create the model

# %%
base_model=tf.keras.applications.NASNetMobile(include_top=False, weights="imagenet",input_tensor=Input(shape=(128,128,3)))

# %%
base_model.summary()
# Out:
# Model: "NASNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  stem_conv1 (Conv2D)         (None, 63, 63, 32)           864       ['input_2[0][0]']
#
#  stem_bn1 (BatchNormalizati  (None, 63, 63, 32)           128       ['stem_conv1[0][0]']
#  on)
#
#  activation_135 (Activation  (None, 63, 63, 32)           0         ['stem_bn1[0][0]']
#  )
#
#  reduction_conv_1_stem_1 (C  (None, 63, 63, 11)           352       ['activation_135[0][0]']
#  onv2D)
#
#  reduction_bn_1_stem_1 (Bat  (None, 63, 63, 11)           44        ['reduction_conv_1_stem_1[0][0
#  chNormalization)                                                   ]']
#
#  activation_136 (Activation  (None, 63, 63, 11)           0         ['reduction_bn_1_stem_1[0][0]'
#  )                                                                  ]
#
#  activation_138 (Activation  (None, 63, 63, 32)           0         ['stem_bn1[0][0]']
#  )
#
#  separable_conv_1_pad_reduc  (None, 67, 67, 11)           0         ['activation_136[0][0]']
#  tion_left1_stem_1 (ZeroPad
#  ding2D)
#
#  separable_conv_1_pad_reduc  (None, 69, 69, 32)           0         ['activation_138[0][0]']
#  tion_right1_stem_1 (ZeroPa
#  dding2D)
#
#  separable_conv_1_reduction  (None, 32, 32, 11)           396       ['separable_conv_1_pad_reducti
#  _left1_stem_1 (SeparableCo                                         on_left1_stem_1[0][0]']
#  nv2D)
#
#  separable_conv_1_reduction  (None, 32, 32, 11)           1920      ['separable_conv_1_pad_reducti
#  _right1_stem_1 (SeparableC                                         on_right1_stem_1[0][0]']
#  onv2D)
#
#  separable_conv_1_bn_reduct  (None, 32, 32, 11)           44        ['separable_conv_1_reduction_l
#  ion_left1_stem_1 (BatchNor                                         eft1_stem_1[0][0]']
#  malization)
#
#  separable_conv_1_bn_reduct  (None, 32, 32, 11)           44        ['separable_conv_1_reduction_r
#  ion_right1_stem_1 (BatchNo                                         ight1_stem_1[0][0]']
#  rmalization)
#
#  activation_137 (Activation  (None, 32, 32, 11)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_left1_stem_1[0][0]']
#
#  activation_139 (Activation  (None, 32, 32, 11)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_right1_stem_1[0][0]']
#
#  separable_conv_2_reduction  (None, 32, 32, 11)           396       ['activation_137[0][0]']
#  _left1_stem_1 (SeparableCo
#  nv2D)
#
#  separable_conv_2_reduction  (None, 32, 32, 11)           660       ['activation_139[0][0]']
#  _right1_stem_1 (SeparableC
#  onv2D)
#
#  activation_140 (Activation  (None, 63, 63, 32)           0         ['stem_bn1[0][0]']
#  )
#
#  separable_conv_2_bn_reduct  (None, 32, 32, 11)           44        ['separable_conv_2_reduction_l
#  ion_left1_stem_1 (BatchNor                                         eft1_stem_1[0][0]']
#  malization)
#
#  separable_conv_2_bn_reduct  (None, 32, 32, 11)           44        ['separable_conv_2_reduction_r
#  ion_right1_stem_1 (BatchNo                                         ight1_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_1_pad_reduc  (None, 69, 69, 32)           0         ['activation_140[0][0]']
#  tion_right2_stem_1 (ZeroPa
#  dding2D)
#
#  activation_142 (Activation  (None, 63, 63, 32)           0         ['stem_bn1[0][0]']
#  )
#
#  reduction_add_1_stem_1 (Ad  (None, 32, 32, 11)           0         ['separable_conv_2_bn_reductio
#  d)                                                                 n_left1_stem_1[0][0]',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right1_stem_1[0][0]']
#
#  separable_conv_1_reduction  (None, 32, 32, 11)           1920      ['separable_conv_1_pad_reducti
#  _right2_stem_1 (SeparableC                                         on_right2_stem_1[0][0]']
#  onv2D)
#
#  separable_conv_1_pad_reduc  (None, 67, 67, 32)           0         ['activation_142[0][0]']
#  tion_right3_stem_1 (ZeroPa
#  dding2D)
#
#  activation_144 (Activation  (None, 32, 32, 11)           0         ['reduction_add_1_stem_1[0][0]
#  )                                                                  ']
#
#  separable_conv_1_bn_reduct  (None, 32, 32, 11)           44        ['separable_conv_1_reduction_r
#  ion_right2_stem_1 (BatchNo                                         ight2_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_1_reduction  (None, 32, 32, 11)           1152      ['separable_conv_1_pad_reducti
#  _right3_stem_1 (SeparableC                                         on_right3_stem_1[0][0]']
#  onv2D)
#
#  separable_conv_1_reduction  (None, 32, 32, 11)           220       ['activation_144[0][0]']
#  _left4_stem_1 (SeparableCo
#  nv2D)
#
#  activation_141 (Activation  (None, 32, 32, 11)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_right2_stem_1[0][0]']
#
#  separable_conv_1_bn_reduct  (None, 32, 32, 11)           44        ['separable_conv_1_reduction_r
#  ion_right3_stem_1 (BatchNo                                         ight3_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_1_bn_reduct  (None, 32, 32, 11)           44        ['separable_conv_1_reduction_l
#  ion_left4_stem_1 (BatchNor                                         eft4_stem_1[0][0]']
#  malization)
#
#  reduction_pad_1_stem_1 (Ze  (None, 65, 65, 11)           0         ['reduction_bn_1_stem_1[0][0]'
#  roPadding2D)                                                       ]
#
#  separable_conv_2_reduction  (None, 32, 32, 11)           660       ['activation_141[0][0]']
#  _right2_stem_1 (SeparableC
#  onv2D)
#
#  activation_143 (Activation  (None, 32, 32, 11)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_right3_stem_1[0][0]']
#
#  activation_145 (Activation  (None, 32, 32, 11)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_left4_stem_1[0][0]']
#
#  reduction_left2_stem_1 (Ma  (None, 32, 32, 11)           0         ['reduction_pad_1_stem_1[0][0]
#  xPooling2D)                                                        ']
#
#  separable_conv_2_bn_reduct  (None, 32, 32, 11)           44        ['separable_conv_2_reduction_r
#  ion_right2_stem_1 (BatchNo                                         ight2_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_2_reduction  (None, 32, 32, 11)           396       ['activation_143[0][0]']
#  _right3_stem_1 (SeparableC
#  onv2D)
#
#  separable_conv_2_reduction  (None, 32, 32, 11)           220       ['activation_145[0][0]']
#  _left4_stem_1 (SeparableCo
#  nv2D)
#
#  adjust_relu_1_stem_2 (Acti  (None, 63, 63, 32)           0         ['stem_bn1[0][0]']
#  vation)
#
#  reduction_add_2_stem_1 (Ad  (None, 32, 32, 11)           0         ['reduction_left2_stem_1[0][0]
#  d)                                                                 ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right2_stem_1[0][0]']
#
#  reduction_left3_stem_1 (Av  (None, 32, 32, 11)           0         ['reduction_pad_1_stem_1[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 32, 32, 11)           44        ['separable_conv_2_reduction_r
#  ion_right3_stem_1 (BatchNo                                         ight3_stem_1[0][0]']
#  rmalization)
#
#  reduction_left4_stem_1 (Av  (None, 32, 32, 11)           0         ['reduction_add_1_stem_1[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 32, 32, 11)           44        ['separable_conv_2_reduction_l
#  ion_left4_stem_1 (BatchNor                                         eft4_stem_1[0][0]']
#  malization)
#
#  reduction_right5_stem_1 (M  (None, 32, 32, 11)           0         ['reduction_pad_1_stem_1[0][0]
#  axPooling2D)                                                       ']
#
#  zero_padding2d_3 (ZeroPadd  (None, 64, 64, 32)           0         ['adjust_relu_1_stem_2[0][0]']
#  ing2D)
#
#  reduction_add3_stem_1 (Add  (None, 32, 32, 11)           0         ['reduction_left3_stem_1[0][0]
#  )                                                                  ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right3_stem_1[0][0]']
#
#  add_3 (Add)                 (None, 32, 32, 11)           0         ['reduction_add_2_stem_1[0][0]
#                                                                     ',
#                                                                      'reduction_left4_stem_1[0][0]
#                                                                     ']
#
#  reduction_add4_stem_1 (Add  (None, 32, 32, 11)           0         ['separable_conv_2_bn_reductio
#  )                                                                  n_left4_stem_1[0][0]',
#                                                                      'reduction_right5_stem_1[0][0
#                                                                     ]']
#
#  cropping2d_3 (Cropping2D)   (None, 63, 63, 32)           0         ['zero_padding2d_3[0][0]']
#
#  reduction_concat_stem_1 (C  (None, 32, 32, 44)           0         ['reduction_add_2_stem_1[0][0]
#  oncatenate)                                                        ',
#                                                                      'reduction_add3_stem_1[0][0]'
#                                                                     , 'add_3[0][0]',
#                                                                      'reduction_add4_stem_1[0][0]'
#                                                                     ]
#
#  adjust_avg_pool_1_stem_2 (  (None, 32, 32, 32)           0         ['adjust_relu_1_stem_2[0][0]']
#  AveragePooling2D)
#
#  adjust_avg_pool_2_stem_2 (  (None, 32, 32, 32)           0         ['cropping2d_3[0][0]']
#  AveragePooling2D)
#
#  activation_146 (Activation  (None, 32, 32, 44)           0         ['reduction_concat_stem_1[0][0
#  )                                                                  ]']
#
#  adjust_conv_1_stem_2 (Conv  (None, 32, 32, 11)           352       ['adjust_avg_pool_1_stem_2[0][
#  2D)                                                                0]']
#
#  adjust_conv_2_stem_2 (Conv  (None, 32, 32, 11)           352       ['adjust_avg_pool_2_stem_2[0][
#  2D)                                                                0]']
#
#  reduction_conv_1_stem_2 (C  (None, 32, 32, 22)           968       ['activation_146[0][0]']
#  onv2D)
#
#  concatenate_3 (Concatenate  (None, 32, 32, 22)           0         ['adjust_conv_1_stem_2[0][0]',
#  )                                                                   'adjust_conv_2_stem_2[0][0]']
#
#  reduction_bn_1_stem_2 (Bat  (None, 32, 32, 22)           88        ['reduction_conv_1_stem_2[0][0
#  chNormalization)                                                   ]']
#
#  adjust_bn_stem_2 (BatchNor  (None, 32, 32, 22)           88        ['concatenate_3[0][0]']
#  malization)
#
#  activation_147 (Activation  (None, 32, 32, 22)           0         ['reduction_bn_1_stem_2[0][0]'
#  )                                                                  ]
#
#  activation_149 (Activation  (None, 32, 32, 22)           0         ['adjust_bn_stem_2[0][0]']
#  )
#
#  separable_conv_1_pad_reduc  (None, 35, 35, 22)           0         ['activation_147[0][0]']
#  tion_left1_stem_2 (ZeroPad
#  ding2D)
#
#  separable_conv_1_pad_reduc  (None, 37, 37, 22)           0         ['activation_149[0][0]']
#  tion_right1_stem_2 (ZeroPa
#  dding2D)
#
#  separable_conv_1_reduction  (None, 16, 16, 22)           1034      ['separable_conv_1_pad_reducti
#  _left1_stem_2 (SeparableCo                                         on_left1_stem_2[0][0]']
#  nv2D)
#
#  separable_conv_1_reduction  (None, 16, 16, 22)           1562      ['separable_conv_1_pad_reducti
#  _right1_stem_2 (SeparableC                                         on_right1_stem_2[0][0]']
#  onv2D)
#
#  separable_conv_1_bn_reduct  (None, 16, 16, 22)           88        ['separable_conv_1_reduction_l
#  ion_left1_stem_2 (BatchNor                                         eft1_stem_2[0][0]']
#  malization)
#
#  separable_conv_1_bn_reduct  (None, 16, 16, 22)           88        ['separable_conv_1_reduction_r
#  ion_right1_stem_2 (BatchNo                                         ight1_stem_2[0][0]']
#  rmalization)
#
#  activation_148 (Activation  (None, 16, 16, 22)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_left1_stem_2[0][0]']
#
#  activation_150 (Activation  (None, 16, 16, 22)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_right1_stem_2[0][0]']
#
#  separable_conv_2_reduction  (None, 16, 16, 22)           1034      ['activation_148[0][0]']
#  _left1_stem_2 (SeparableCo
#  nv2D)
#
#  separable_conv_2_reduction  (None, 16, 16, 22)           1562      ['activation_150[0][0]']
#  _right1_stem_2 (SeparableC
#  onv2D)
#
#  activation_151 (Activation  (None, 32, 32, 22)           0         ['adjust_bn_stem_2[0][0]']
#  )
#
#  separable_conv_2_bn_reduct  (None, 16, 16, 22)           88        ['separable_conv_2_reduction_l
#  ion_left1_stem_2 (BatchNor                                         eft1_stem_2[0][0]']
#  malization)
#
#  separable_conv_2_bn_reduct  (None, 16, 16, 22)           88        ['separable_conv_2_reduction_r
#  ion_right1_stem_2 (BatchNo                                         ight1_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_1_pad_reduc  (None, 37, 37, 22)           0         ['activation_151[0][0]']
#  tion_right2_stem_2 (ZeroPa
#  dding2D)
#
#  activation_153 (Activation  (None, 32, 32, 22)           0         ['adjust_bn_stem_2[0][0]']
#  )
#
#  reduction_add_1_stem_2 (Ad  (None, 16, 16, 22)           0         ['separable_conv_2_bn_reductio
#  d)                                                                 n_left1_stem_2[0][0]',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right1_stem_2[0][0]']
#
#  separable_conv_1_reduction  (None, 16, 16, 22)           1562      ['separable_conv_1_pad_reducti
#  _right2_stem_2 (SeparableC                                         on_right2_stem_2[0][0]']
#  onv2D)
#
#  separable_conv_1_pad_reduc  (None, 35, 35, 22)           0         ['activation_153[0][0]']
#  tion_right3_stem_2 (ZeroPa
#  dding2D)
#
#  activation_155 (Activation  (None, 16, 16, 22)           0         ['reduction_add_1_stem_2[0][0]
#  )                                                                  ']
#
#  separable_conv_1_bn_reduct  (None, 16, 16, 22)           88        ['separable_conv_1_reduction_r
#  ion_right2_stem_2 (BatchNo                                         ight2_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_1_reduction  (None, 16, 16, 22)           1034      ['separable_conv_1_pad_reducti
#  _right3_stem_2 (SeparableC                                         on_right3_stem_2[0][0]']
#  onv2D)
#
#  separable_conv_1_reduction  (None, 16, 16, 22)           682       ['activation_155[0][0]']
#  _left4_stem_2 (SeparableCo
#  nv2D)
#
#  activation_152 (Activation  (None, 16, 16, 22)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_right2_stem_2[0][0]']
#
#  separable_conv_1_bn_reduct  (None, 16, 16, 22)           88        ['separable_conv_1_reduction_r
#  ion_right3_stem_2 (BatchNo                                         ight3_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_1_bn_reduct  (None, 16, 16, 22)           88        ['separable_conv_1_reduction_l
#  ion_left4_stem_2 (BatchNor                                         eft4_stem_2[0][0]']
#  malization)
#
#  reduction_pad_1_stem_2 (Ze  (None, 33, 33, 22)           0         ['reduction_bn_1_stem_2[0][0]'
#  roPadding2D)                                                       ]
#
#  separable_conv_2_reduction  (None, 16, 16, 22)           1562      ['activation_152[0][0]']
#  _right2_stem_2 (SeparableC
#  onv2D)
#
#  activation_154 (Activation  (None, 16, 16, 22)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_right3_stem_2[0][0]']
#
#  activation_156 (Activation  (None, 16, 16, 22)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_left4_stem_2[0][0]']
#
#  reduction_left2_stem_2 (Ma  (None, 16, 16, 22)           0         ['reduction_pad_1_stem_2[0][0]
#  xPooling2D)                                                        ']
#
#  separable_conv_2_bn_reduct  (None, 16, 16, 22)           88        ['separable_conv_2_reduction_r
#  ion_right2_stem_2 (BatchNo                                         ight2_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_2_reduction  (None, 16, 16, 22)           1034      ['activation_154[0][0]']
#  _right3_stem_2 (SeparableC
#  onv2D)
#
#  separable_conv_2_reduction  (None, 16, 16, 22)           682       ['activation_156[0][0]']
#  _left4_stem_2 (SeparableCo
#  nv2D)
#
#  adjust_relu_1_0 (Activatio  (None, 32, 32, 44)           0         ['reduction_concat_stem_1[0][0
#  n)                                                                 ]']
#
#  reduction_add_2_stem_2 (Ad  (None, 16, 16, 22)           0         ['reduction_left2_stem_2[0][0]
#  d)                                                                 ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right2_stem_2[0][0]']
#
#  reduction_left3_stem_2 (Av  (None, 16, 16, 22)           0         ['reduction_pad_1_stem_2[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 16, 16, 22)           88        ['separable_conv_2_reduction_r
#  ion_right3_stem_2 (BatchNo                                         ight3_stem_2[0][0]']
#  rmalization)
#
#  reduction_left4_stem_2 (Av  (None, 16, 16, 22)           0         ['reduction_add_1_stem_2[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 16, 16, 22)           88        ['separable_conv_2_reduction_l
#  ion_left4_stem_2 (BatchNor                                         eft4_stem_2[0][0]']
#  malization)
#
#  reduction_right5_stem_2 (M  (None, 16, 16, 22)           0         ['reduction_pad_1_stem_2[0][0]
#  axPooling2D)                                                       ']
#
#  zero_padding2d_4 (ZeroPadd  (None, 33, 33, 44)           0         ['adjust_relu_1_0[0][0]']
#  ing2D)
#
#  reduction_add3_stem_2 (Add  (None, 16, 16, 22)           0         ['reduction_left3_stem_2[0][0]
#  )                                                                  ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right3_stem_2[0][0]']
#
#  add_4 (Add)                 (None, 16, 16, 22)           0         ['reduction_add_2_stem_2[0][0]
#                                                                     ',
#                                                                      'reduction_left4_stem_2[0][0]
#                                                                     ']
#
#  reduction_add4_stem_2 (Add  (None, 16, 16, 22)           0         ['separable_conv_2_bn_reductio
#  )                                                                  n_left4_stem_2[0][0]',
#                                                                      'reduction_right5_stem_2[0][0
#                                                                     ]']
#
#  cropping2d_4 (Cropping2D)   (None, 32, 32, 44)           0         ['zero_padding2d_4[0][0]']
#
#  reduction_concat_stem_2 (C  (None, 16, 16, 88)           0         ['reduction_add_2_stem_2[0][0]
#  oncatenate)                                                        ',
#                                                                      'reduction_add3_stem_2[0][0]'
#                                                                     , 'add_4[0][0]',
#                                                                      'reduction_add4_stem_2[0][0]'
#                                                                     ]
#
#  adjust_avg_pool_1_0 (Avera  (None, 16, 16, 44)           0         ['adjust_relu_1_0[0][0]']
#  gePooling2D)
#
#  adjust_avg_pool_2_0 (Avera  (None, 16, 16, 44)           0         ['cropping2d_4[0][0]']
#  gePooling2D)
#
#  adjust_conv_1_0 (Conv2D)    (None, 16, 16, 22)           968       ['adjust_avg_pool_1_0[0][0]']
#
#  adjust_conv_2_0 (Conv2D)    (None, 16, 16, 22)           968       ['adjust_avg_pool_2_0[0][0]']
#
#  activation_157 (Activation  (None, 16, 16, 88)           0         ['reduction_concat_stem_2[0][0
#  )                                                                  ]']
#
#  concatenate_4 (Concatenate  (None, 16, 16, 44)           0         ['adjust_conv_1_0[0][0]',
#  )                                                                   'adjust_conv_2_0[0][0]']
#
#  normal_conv_1_0 (Conv2D)    (None, 16, 16, 44)           3872      ['activation_157[0][0]']
#
#  adjust_bn_0 (BatchNormaliz  (None, 16, 16, 44)           176       ['concatenate_4[0][0]']
#  ation)
#
#  normal_bn_1_0 (BatchNormal  (None, 16, 16, 44)           176       ['normal_conv_1_0[0][0]']
#  ization)
#
#  activation_158 (Activation  (None, 16, 16, 44)           0         ['normal_bn_1_0[0][0]']
#  )
#
#  activation_160 (Activation  (None, 16, 16, 44)           0         ['adjust_bn_0[0][0]']
#  )
#
#  activation_162 (Activation  (None, 16, 16, 44)           0         ['adjust_bn_0[0][0]']
#  )
#
#  activation_164 (Activation  (None, 16, 16, 44)           0         ['adjust_bn_0[0][0]']
#  )
#
#  activation_166 (Activation  (None, 16, 16, 44)           0         ['normal_bn_1_0[0][0]']
#  )
#
#  separable_conv_1_normal_le  (None, 16, 16, 44)           3036      ['activation_158[0][0]']
#  ft1_0 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 16, 16, 44)           2332      ['activation_160[0][0]']
#  ght1_0 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 16, 16, 44)           3036      ['activation_162[0][0]']
#  ft2_0 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 16, 16, 44)           2332      ['activation_164[0][0]']
#  ght2_0 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 16, 16, 44)           2332      ['activation_166[0][0]']
#  ft5_0 (SeparableConv2D)
#
#  separable_conv_1_bn_normal  (None, 16, 16, 44)           176       ['separable_conv_1_normal_left
#  _left1_0 (BatchNormalizati                                         1_0[0][0]']
#  on)
#
#  separable_conv_1_bn_normal  (None, 16, 16, 44)           176       ['separable_conv_1_normal_righ
#  _right1_0 (BatchNormalizat                                         t1_0[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 16, 16, 44)           176       ['separable_conv_1_normal_left
#  _left2_0 (BatchNormalizati                                         2_0[0][0]']
#  on)
#
#  separable_conv_1_bn_normal  (None, 16, 16, 44)           176       ['separable_conv_1_normal_righ
#  _right2_0 (BatchNormalizat                                         t2_0[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 16, 16, 44)           176       ['separable_conv_1_normal_left
#  _left5_0 (BatchNormalizati                                         5_0[0][0]']
#  on)
#
#  activation_159 (Activation  (None, 16, 16, 44)           0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft1_0[0][0]']
# ...
#                                                                      'normal_add_5_11[0][0]']
#
#  activation_310 (Activation  (None, 4, 4, 1056)           0         ['normal_concat_10[0][0]']
#  )
#
#  activation_311 (Activation  (None, 4, 4, 1056)           0         ['normal_concat_11[0][0]']
#  )
#
#  adjust_conv_projection_12   (None, 4, 4, 176)            185856    ['activation_310[0][0]']
#  (Conv2D)
#
#  normal_conv_1_12 (Conv2D)   (None, 4, 4, 176)            185856    ['activation_311[0][0]']
#
#  adjust_bn_12 (BatchNormali  (None, 4, 4, 176)            704       ['adjust_conv_projection_12[0]
#  zation)                                                            [0]']
#
#  normal_bn_1_12 (BatchNorma  (None, 4, 4, 176)            704       ['normal_conv_1_12[0][0]']
#  lization)
#
#  activation_312 (Activation  (None, 4, 4, 176)            0         ['normal_bn_1_12[0][0]']
#  )
#
#  activation_314 (Activation  (None, 4, 4, 176)            0         ['adjust_bn_12[0][0]']
#  )
#
#  activation_316 (Activation  (None, 4, 4, 176)            0         ['adjust_bn_12[0][0]']
#  )
#
#  activation_318 (Activation  (None, 4, 4, 176)            0         ['adjust_bn_12[0][0]']
#  )
#
#  activation_320 (Activation  (None, 4, 4, 176)            0         ['normal_bn_1_12[0][0]']
#  )
#
#  separable_conv_1_normal_le  (None, 4, 4, 176)            35376     ['activation_312[0][0]']
#  ft1_12 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 4, 4, 176)            32560     ['activation_314[0][0]']
#  ght1_12 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 4, 4, 176)            35376     ['activation_316[0][0]']
#  ft2_12 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 4, 4, 176)            32560     ['activation_318[0][0]']
#  ght2_12 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 4, 4, 176)            32560     ['activation_320[0][0]']
#  ft5_12 (SeparableConv2D)
#
#  separable_conv_1_bn_normal  (None, 4, 4, 176)            704       ['separable_conv_1_normal_left
#  _left1_12 (BatchNormalizat                                         1_12[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 4, 4, 176)            704       ['separable_conv_1_normal_righ
#  _right1_12 (BatchNormaliza                                         t1_12[0][0]']
#  tion)
#
#  separable_conv_1_bn_normal  (None, 4, 4, 176)            704       ['separable_conv_1_normal_left
#  _left2_12 (BatchNormalizat                                         2_12[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 4, 4, 176)            704       ['separable_conv_1_normal_righ
#  _right2_12 (BatchNormaliza                                         t2_12[0][0]']
#  tion)
#
#  separable_conv_1_bn_normal  (None, 4, 4, 176)            704       ['separable_conv_1_normal_left
#  _left5_12 (BatchNormalizat                                         5_12[0][0]']
#  ion)
#
#  activation_313 (Activation  (None, 4, 4, 176)            0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft1_12[0][0]']
#
#  activation_315 (Activation  (None, 4, 4, 176)            0         ['separable_conv_1_bn_normal_r
#  )                                                                  ight1_12[0][0]']
#
#  activation_317 (Activation  (None, 4, 4, 176)            0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft2_12[0][0]']
#
#  activation_319 (Activation  (None, 4, 4, 176)            0         ['separable_conv_1_bn_normal_r
#  )                                                                  ight2_12[0][0]']
#
#  activation_321 (Activation  (None, 4, 4, 176)            0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft5_12[0][0]']
#
#  separable_conv_2_normal_le  (None, 4, 4, 176)            35376     ['activation_313[0][0]']
#  ft1_12 (SeparableConv2D)
#
#  separable_conv_2_normal_ri  (None, 4, 4, 176)            32560     ['activation_315[0][0]']
#  ght1_12 (SeparableConv2D)
#
#  separable_conv_2_normal_le  (None, 4, 4, 176)            35376     ['activation_317[0][0]']
#  ft2_12 (SeparableConv2D)
#
#  separable_conv_2_normal_ri  (None, 4, 4, 176)            32560     ['activation_319[0][0]']
#  ght2_12 (SeparableConv2D)
#
#  separable_conv_2_normal_le  (None, 4, 4, 176)            32560     ['activation_321[0][0]']
#  ft5_12 (SeparableConv2D)
#
#  separable_conv_2_bn_normal  (None, 4, 4, 176)            704       ['separable_conv_2_normal_left
#  _left1_12 (BatchNormalizat                                         1_12[0][0]']
#  ion)
#
#  separable_conv_2_bn_normal  (None, 4, 4, 176)            704       ['separable_conv_2_normal_righ
#  _right1_12 (BatchNormaliza                                         t1_12[0][0]']
#  tion)
#
#  separable_conv_2_bn_normal  (None, 4, 4, 176)            704       ['separable_conv_2_normal_left
#  _left2_12 (BatchNormalizat                                         2_12[0][0]']
#  ion)
#
#  separable_conv_2_bn_normal  (None, 4, 4, 176)            704       ['separable_conv_2_normal_righ
#  _right2_12 (BatchNormaliza                                         t2_12[0][0]']
#  tion)
#
#  normal_left3_12 (AveragePo  (None, 4, 4, 176)            0         ['normal_bn_1_12[0][0]']
#  oling2D)
#
#  normal_left4_12 (AveragePo  (None, 4, 4, 176)            0         ['adjust_bn_12[0][0]']
#  oling2D)
#
#  normal_right4_12 (AverageP  (None, 4, 4, 176)            0         ['adjust_bn_12[0][0]']
#  ooling2D)
#
#  separable_conv_2_bn_normal  (None, 4, 4, 176)            704       ['separable_conv_2_normal_left
#  _left5_12 (BatchNormalizat                                         5_12[0][0]']
#  ion)
#
#  normal_add_1_12 (Add)       (None, 4, 4, 176)            0         ['separable_conv_2_bn_normal_l
#                                                                     eft1_12[0][0]',
#                                                                      'separable_conv_2_bn_normal_r
#                                                                     ight1_12[0][0]']
#
#  normal_add_2_12 (Add)       (None, 4, 4, 176)            0         ['separable_conv_2_bn_normal_l
#                                                                     eft2_12[0][0]',
#                                                                      'separable_conv_2_bn_normal_r
#                                                                     ight2_12[0][0]']
#
#  normal_add_3_12 (Add)       (None, 4, 4, 176)            0         ['normal_left3_12[0][0]',
#                                                                      'adjust_bn_12[0][0]']
#
#  normal_add_4_12 (Add)       (None, 4, 4, 176)            0         ['normal_left4_12[0][0]',
#                                                                      'normal_right4_12[0][0]']
#
#  normal_add_5_12 (Add)       (None, 4, 4, 176)            0         ['separable_conv_2_bn_normal_l
#                                                                     eft5_12[0][0]',
#                                                                      'normal_bn_1_12[0][0]']
#
#  normal_concat_12 (Concaten  (None, 4, 4, 1056)           0         ['adjust_bn_12[0][0]',
#  ate)                                                                'normal_add_1_12[0][0]',
#                                                                      'normal_add_2_12[0][0]',
#                                                                      'normal_add_3_12[0][0]',
#                                                                      'normal_add_4_12[0][0]',
#                                                                      'normal_add_5_12[0][0]']
#
#  activation_322 (Activation  (None, 4, 4, 1056)           0         ['normal_concat_12[0][0]']
#  )
#
# ==================================================================================================
# Total params: 4269716 (16.29 MB)
# Trainable params: 4232978 (16.15 MB)
# Non-trainable params: 36738 (143.51 KB)
# __________________________________________________________________________________________________

# %%
base_model.trainable = False

# %%
model_name='NasNetMobile'
print("Building model with", base_model)
model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),  # Converts feature maps into a single 1D feature vector
    tf.keras.layers.Dense(512, activation='relu'),  # Increased units for 3-class classification
    tf.keras.layers.Dropout(0.4),  # Slightly reduced dropout to prevent underfitting
    tf.keras.layers.Dense(256, activation='relu'),  # Additional dense layer for better feature extraction
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(3, activation='softmax')  # Output layer with 3 classes
])

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),  # Reduced learning rate for better convergence
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# Building model with <keras.src.engine.functional.Functional object at 0x00000242983733D0>

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  NASNet (Functional)         (None, 4, 4, 1056)        4269716
#
#  global_average_pooling2d (  (None, 1056)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               541184
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 4942999 (18.86 MB)
# Trainable params: 673283 (2.57 MB)
# Non-trainable params: 4269716 (16.29 MB)
# _________________________________________________________________

# %%
epochs =20

history=model.fit(x=train_gen, epochs=epochs, validation_data=valid_gen)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From c:\Users\Ahmad Lutfi\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Ahmad Lutfi\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 37/37 [==============================] - 38s 766ms/step - loss: 1.2504 - accuracy: 0.4662 - val_loss: 0.7327 - val_accuracy: 0.6266
# Epoch 2/20
# 37/37 [==============================] - 8s 220ms/step - loss: 0.8571 - accuracy: 0.6267 - val_loss: 0.6576 - val_accuracy: 0.6835
# Epoch 3/20
# 37/37 [==============================] - 9s 236ms/step - loss: 0.7468 - accuracy: 0.6681 - val_loss: 0.5758 - val_accuracy: 0.7532
# Epoch 4/20
# 37/37 [==============================] - 9s 230ms/step - loss: 0.6856 - accuracy: 0.6858 - val_loss: 0.5494 - val_accuracy: 0.7532
# Epoch 5/20
# 37/37 [==============================] - 9s 232ms/step - loss: 0.6531 - accuracy: 0.7179 - val_loss: 0.5339 - val_accuracy: 0.7278
# Epoch 6/20
# 37/37 [==============================] - 8s 213ms/step - loss: 0.6145 - accuracy: 0.7289 - val_loss: 0.5345 - val_accuracy: 0.7405
# Epoch 7/20
# 37/37 [==============================] - 8s 209ms/step - loss: 0.5856 - accuracy: 0.7458 - val_loss: 0.5078 - val_accuracy: 0.7405
# Epoch 8/20
# 37/37 [==============================] - 7s 184ms/step - loss: 0.5678 - accuracy: 0.7424 - val_loss: 0.5101 - val_accuracy: 0.7595
# Epoch 9/20
# 37/37 [==============================] - 8s 208ms/step - loss: 0.5463 - accuracy: 0.7466 - val_loss: 0.5081 - val_accuracy: 0.7468
# Epoch 10/20
# 37/37 [==============================] - 8s 220ms/step - loss: 0.5239 - accuracy: 0.7677 - val_loss: 0.5028 - val_accuracy: 0.7532
# Epoch 11/20
# 37/37 [==============================] - 7s 193ms/step - loss: 0.5307 - accuracy: 0.7416 - val_loss: 0.5091 - val_accuracy: 0.7405
# Epoch 12/20
# 37/37 [==============================] - 7s 195ms/step - loss: 0.4913 - accuracy: 0.7753 - val_loss: 0.5017 - val_accuracy: 0.7848
# Epoch 13/20
# 37/37 [==============================] - 7s 196ms/step - loss: 0.4891 - accuracy: 0.7804 - val_loss: 0.5164 - val_accuracy: 0.7468
# Epoch 14/20
# 37/37 [==============================] - 8s 213ms/step - loss: 0.4875 - accuracy: 0.7846 - val_loss: 0.5204 - val_accuracy: 0.7468
# Epoch 15/20
# 37/37 [==============================] - 8s 211ms/step - loss: 0.4857 - accuracy: 0.7863 - val_loss: 0.5036 - val_accuracy: 0.7532
# Epoch 16/20
# 37/37 [==============================] - 8s 210ms/step - loss: 0.4380 - accuracy: 0.7981 - val_loss: 0.5068 - val_accuracy: 0.7595
# Epoch 17/20
# 37/37 [==============================] - 8s 201ms/step - loss: 0.4477 - accuracy: 0.7981 - val_loss: 0.4958 - val_accuracy: 0.7722
# Epoch 18/20
# 37/37 [==============================] - 8s 210ms/step - loss: 0.4244 - accuracy: 0.8150 - val_loss: 0.5039 - val_accuracy: 0.7658
# Epoch 19/20
# 37/37 [==============================] - 9s 233ms/step - loss: 0.4219 - accuracy: 0.8209 - val_loss: 0.4839 - val_accuracy: 0.7848
# Epoch 20/20
# 37/37 [==============================] - 8s 207ms/step - loss: 0.4148 - accuracy: 0.8091 - val_loss: 0.4887 - val_accuracy: 0.7975

# %% [markdown]
# ### define function to print text in RGB foreground and background colors

# %%
def print_in_color(txt_msg,fore_tupple,back_tupple,):
    #prints the text_msg in the foreground color specified by fore_tupple with the background specified by back_tupple 
    #text_msg is the text, fore_tupple is foregroud color tupple (r,g,b), back_tupple is background tupple (r,g,b)
    rf,gf,bf=fore_tupple
    rb,gb,bb=back_tupple
    msg='{0}' + txt_msg
    mat='\33[38;2;' + str(rf) +';' + str(gf) + ';' + str(bf) + ';48;2;' + str(rb) + ';' +str(gb) + ';' + str(bb) +'m' 
    print(msg .format(mat), flush=True)
    print('\33[0m', flush=True) # returns default print color to back to black
    return

# %% [markdown]
# ### define function to plot the training data

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout
    #plt.style.use('fivethirtyeight')
    plt.show()

# %% [markdown]
# ### define function to generate the confusion matrix and classification report

# %%
def print_info( test_gen, preds, print_code, save_dir, subject ):
    class_dict=test_gen.class_indices
    labels= test_gen.labels
    file_names= test_gen.filenames 
    error_list=[]
    true_class=[]
    pred_class=[]
    prob_list=[]
    new_dict={}
    error_indices=[]
    y_pred=[]
    for key,value in class_dict.items():
        new_dict[value]=key             # dictionary {integer of class number: string of class name}
    # store new_dict as a text fine in the save_dir
    classes=list(new_dict.values())     # list of string of class names
    dict_as_text=str(new_dict)
    dict_name= subject + '-' +str(len(classes)) +'.txt'  
    dict_path=os.path.join(save_dir,dict_name)    
    with open(dict_path, 'w') as x_file:
        x_file.write(dict_as_text)    
    errors=0      
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)        
        true_index=labels[i]  # labels are integer values
        if pred_index != true_index: # a misclassification has occurred
            error_list.append(file_names[i])
            true_class.append(new_dict[true_index])
            pred_class.append(new_dict[pred_index])
            prob_list.append(p[pred_index])
            error_indices.append(true_index)            
            errors=errors + 1
        y_pred.append(pred_index)    
    if print_code !=0:
        if errors>0:
            if print_code>errors:
                r=errors
            else:
                r=print_code           
            msg='{0:^28s}{1:^28s}{2:^28s}{3:^16s}'.format('Filename', 'Predicted Class' , 'True Class', 'Probability')
            print_in_color(msg, (0,255,0),(55,65,80))
            for i in range(r):                
                split1=os.path.split(error_list[i])                
                split2=os.path.split(split1[0])                
                fname=split2[1] + '/' + split1[1]
                msg='{0:^28s}{1:^28s}{2:^28s}{3:4s}{4:^6.4f}'.format(fname, pred_class[i],true_class[i], ' ', prob_list[i])
                print_in_color(msg, (255,255,255), (55,65,60))
                #print(error_list[i]  , pred_class[i], true_class[i], prob_list[i])               
        else:
            msg='With accuracy of 100 % there are no errors to print'
            print_in_color(msg, (0,255,0),(55,65,80))
    if errors>0:
        plot_bar=[]
        plot_class=[]
        for  key, value in new_dict.items():        
            count=error_indices.count(key) 
            if count!=0:
                plot_bar.append(count) # list containg how many times a class c had an error
                plot_class.append(value)   # stores the class 
        fig=plt.figure()
        fig.set_figheight(len(plot_class)/3)
        fig.set_figwidth(10)
        plt.style.use('fivethirtyeight')
        for i in range(0, len(plot_class)):
            c=plot_class[i]
            x=plot_bar[i]
            plt.barh(c, x, )
            plt.title( ' Errors by Class on Test Set')
    y_true= np.array(labels)        
    y_pred=np.array(y_pred)
    if len(classes)<= 30:
        # create a confusion matrix 
        cm = confusion_matrix(y_true, y_pred )        
        length=len(classes)
        if length<8:
            fig_width=8
            fig_height=8
        else:
            fig_width= int(length * .5)
            fig_height= int(length * .5)
        plt.figure(figsize=(fig_width, fig_height))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(length)+.5, classes, rotation= 90)
        plt.yticks(np.arange(length)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes)
    print("Classification Report:\n----------------------\n", clr)

# %% [markdown]
# ### evaluate model on the test set then save the model

# %%
tr_plot(history,0)
save_dir=r'./'
subject='egg'
acc=model.evaluate( test_gen, batch_size=test_batch_size, verbose=1, steps=test_steps, return_dict=False)[1]*100
msg=f'accuracy on the test set is {acc:5.2f} %'
print_in_color(msg, (0,255,0),(55,65,80))
save_id=str (model_name + '.h5')
save_loc=os.path.join(save_dir, save_id)
model.save(save_loc)
# Out:
# 3/3 [==============================] - 4s 1s/step - loss: 0.5541 - accuracy: 0.7890
# accuracy on the test set is 78.90 %
# c:\Users\Ahmad Lutfi\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ### make predictions on test set and generate confusion matrix and classification report

# %%
print_code=0
preds=model.predict(test_gen) 
print_info( test_gen, preds, print_code, save_dir, subject )
# Out:
# 3/3 [==============================] - 8s 430ms/step
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#       Mutu I       0.82      0.77      0.79        82
#      Mutu II       0.66      0.73      0.69        73
#     Mutu III       0.89      0.87      0.88        82
#
#     accuracy                           0.79       237
#    macro avg       0.79      0.79      0.79       237
# weighted avg       0.79      0.79      0.79       237
